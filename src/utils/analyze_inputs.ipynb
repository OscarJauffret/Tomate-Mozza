# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV (update the path if needed)
df = pd.read_csv("../../inputs.2025-03-27_20-18-07.csv")

# Basic statistics
display(df.describe())
# Out:
#                   x             y     next_turn      velocity  acceleration  \
# count  74333.000000  74333.000000  74333.000000  74333.000000  74333.000000
# mean       0.305875      0.016101     -0.995614      0.298041      0.262891
# std        0.201889      0.522361      0.093553      0.188854      0.868686
# min       -0.080949     -1.755543     -1.000000      0.000000    -14.908775
# 25%        0.135242     -0.321358     -1.000000      0.137330     -0.265878
# 50%        0.258373      0.000000     -1.000000      0.293789      0.215148
# 75%        0.434322      0.365498     -1.000000      0.452319      0.950593
# max        1.024020      1.897392      1.000000      0.900913      1.862200
#
#                 yaw
# count  74333.000000
# mean       0.007661
# std        0.180296
# min       -0.899519
# 25%       -0.063915
# 50%        0.000000
# 75%        0.077409
# max        0.993373

# %%
# Plot distributions
features = ["x", "y", "next_turn", "velocity", "acceleration", "yaw"]
for feature in features:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[feature], bins=50, kde=True)
    plt.title(f"Distribution of {feature}")
    plt.grid(True)
    plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(6, 4))
sns.heatmap(df[features].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.show()
